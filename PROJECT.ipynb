# %%
from __future__ import print_function, division

# %matplotlib inline

import pandas as pd
import numpy as np

import thinkstats2
import thinkplot

# %% [markdown]
# SECTION 1

# %% [markdown]
# What is the relationship between the variables homeWon and awayLost from the dataset basketball_teams

# %% [markdown]
# SECTION 2

# %%
df = pd.read_csv("basketball_teams.csv")
df
# Out:
#       year lgID tmID franchID confID divID  rank  confRank playoff  \
# 0     1946  NBA  BOS      BOS    NaN    ED     5         0     NaN
# 1     1946  NBA  CHS      CHS    NaN    WD     1         0       F
# 2     1946  NBA  CLR      CLR    NaN    WD     3         0      R1
# 3     1946  NBA  DTF      DTF    NaN    WD     4         0     NaN
# 4     1946  NBA  NYK      NYK    NaN    ED     3         0      SF
# 5     1946  NBA  PHW      GSW    NaN    ED     2         0      NC
# 6     1946  NBA  PIT      PIT    NaN    WD     5         0     NaN
# 7     1946  NBA  PRO      PRO    NaN    ED     4         0     NaN
# 8     1946  NBA  STB      STB    NaN    WD     2         0      R1
# 9     1946  NBA  TRH      TRH    NaN    ED     5         0     NaN
# 10    1946  NBA  WSC      WSC    NaN    ED     1         0      SF
# 11    1947  NBA  BLB      BLB    NaN    WD     2         0      NC
# 12    1947  NBA  BOS      BOS    NaN    ED     3         0      R1
# ...

# %%
df.homeWon.value_counts().sort_index()
# Out:
# 0     107
# 1      13
# 2       7
# 3       7
# 4       9
# 5       5
# 6       9
# 7      12
# 8      11
# 9      24
# 10     19
# 11     29
# 12     30
# 13     31
# 14     35
# 15     40
# 16     32
# 17     41
# 18     59
# 19     42
# 20     55
# 21     55
# 22     65
# 23     54
# 24     57
# 25     75
# 26     73
# 27     68
# 28     61
# 29     69
# 30     67
# 31     72
# 32     42
# 33     44
# 34     28
# 35     29
# 36     32
# 37     16
# 38      3
# 39      7
# 40      2
# Name: homeWon, dtype: int64

# %%
df.awayLost.value_counts().sort_index()
# Out:
# 0     107
# 1       6
# 2       8
# 3       4
# 4       8
# 5       6
# 6       8
# 7      14
# 8       8
# 9      11
# 10     25
# 11     15
# 12     21
# 13     20
# 14     42
# 15     46
# 16     39
# 17     45
# 18     45
# 19     68
# 20     62
# 21     76
# 22     80
# 23     75
# 24     61
# 25     75
# 26     82
# 27     62
# 28     52
# 29     61
# 30     40
# 31     58
# 32     47
# 33     46
# 34     37
# 35     36
# 36     14
# 37     12
# 38     11
# 39      2
# 40      1
# Name: awayLost, dtype: int64

# %% [markdown]
# SECTION 3

# %%
df.homeWon.describe()
# Out:
# count    1536.000000
# mean       21.361328
# std         9.846326
# min         0.000000
# 25%        15.000000
# 50%        23.000000
# 75%        29.000000
# max        40.000000
# Name: homeWon, dtype: float64

# %%
df.awayLost.describe()
# Out:
# count    1536.000000
# mean       21.363281
# std         9.429432
# min         0.000000
# 25%        16.000000
# 50%        23.000000
# 75%        28.000000
# max        40.000000
# Name: awayLost, dtype: float64

# %%
hist1 = thinkstats2.Hist(df.homeWon, label='home games won')
hist2 = thinkstats2.Hist(df.awayLost, label='away games lost')
thinkplot.Hist(hist1,align='left',width=0.5,color='blue')
thinkplot.Hist(hist2,align='right',width=0.5,color='red')
thinkplot.Config(xlabel='game result', ylabel='Frequency')

# %%
pmf1 = thinkstats2.Pmf(df.homeWon, label='home games won')
pmf2 = thinkstats2.Pmf(df.awayLost, label='away games lost')

thinkplot.Pmfs([pmf1,pmf2])
thinkplot.Config(xlabel='game result')

# %%
cdf1 = thinkstats2.Cdf(df['homeWon'], label='home games won')
cdf2 = thinkstats2.Cdf(df['awayLost'], label='away games lost')

thinkplot.PrePlot(2)
thinkplot.Cdfs([cdf1, cdf2])
thinkplot.Config(xlabel='game result', ylabel='CDF', loc='upper left')

# %% [markdown]
# SECTION 4

# %%
mean, std = df["homeWon"].mean(), df["homeWon"].std()
mean, std
pdf = thinkstats2.NormalPdf(mean, std)
pdf.Density(mean + std)
thinkplot.Pdf(pdf, label='normal')
thinkplot.Config(xlabel='x', ylabel='PDF')

# %%
thinkplot.Pdf(pdf, label='normal')

sample = np.random.normal(mean, std, 500)
sample_pdf = thinkstats2.EstimatedPdf(sample, label='sample')
thinkplot.Pdf(sample_pdf, label='sample KDE')
thinkplot.Config(xlabel='x', ylabel='PDF')

# %%
mean1, std1 = df["awayLost"].mean(), df["awayLost"].std()
mean1, std1
pdf = thinkstats2.NormalPdf(mean1, std1)
pdf.Density(mean1 + std1)
thinkplot.Pdf(pdf, label='normal')
thinkplot.Config(xlabel='x', ylabel='PDF')

# %%
thinkplot.Pdf(pdf, label='normal')

sample = np.random.normal(mean1, std1, 500)
sample_pdf = thinkstats2.EstimatedPdf(sample, label='sample')
thinkplot.Pdf(sample_pdf, label='sample KDE')
thinkplot.Config(xlabel='x', ylabel='PDF')

# %% [markdown]
# SECTION 5

# %%
def Jitter(values, jitter=0.5):
    n = len(values)
    return np.random.normal(0, jitter, n) + values

homeWon =  df.homeWon
awayLost = df.awayLost

thinkplot.Scatter(Jitter(homeWon),Jitter(awayLost), color='blue')
thinkplot.Config(xlabel='awayLost',
                 ylabel='homeWon')

# %%
df.awayLost.value_counts().sort_index()
# Out:
# 0     107
# 1       6
# 2       8
# 3       4
# 4       8
# 5       6
# 6       8
# 7      14
# 8       8
# 9      11
# 10     25
# 11     15
# 12     21
# 13     20
# 14     42
# 15     46
# 16     39
# 17     45
# 18     45
# 19     68
# 20     62
# 21     76
# 22     80
# 23     75
# 24     61
# 25     75
# 26     82
# 27     62
# 28     52
# 29     61
# 30     40
# 31     58
# 32     47
# 33     46
# 34     37
# 35     36
# 36     14
# 37     12
# 38     11
# 39      2
# 40      1
# Name: awayLost, dtype: int64

# %%
bins = np.arange(0, 40, 5)
indices = np.digitize(df.homeWon, bins)
groups = df.groupby(indices)

for i, group in groups:
    print(i, len(group))
# Out:
# 1 143
# 2 61
# 3 144
# 4 214
# 5 286
# 6 346
# 7 253
# 8 89

# %%
homeWmean = [group.homeWon.mean() for i, group in groups]
cdfs = [thinkstats2.Cdf(group.awayLost) for i, group in groups]
homeWmean
# Out:
# [0.5874125874125874,
#  7.655737704918033,
#  12.23611111111111,
#  17.14485981308411,
#  22.01048951048951,
#  26.930635838150287,
#  31.58102766798419,
#  36.247191011235955]

# %%
CustomColors = ["black","blue","yellow"]
percent = [25, 50, 75]
for i in range(len(percent)):
    awayLost_percentiles = [cdf.Percentile(percent[i]) for cdf in cdfs]
    label = '%dth' % percent[i]
    thinkplot.Plot(homeWmean, awayLost_percentiles, label=label,color=CustomColors[i])

# %%
def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)

    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov

def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    meanx, varx = thinkstats2.MeanVar(xs)
    meany, vary = thinkstats2.MeanVar(ys)

    corr = Cov(xs, ys, meanx, meany) / np.sqrt(varx * vary)
    return corr

def SpearmanCorr(xs, ys):
    xranks = pd.Series(xs).rank()
    yranks = pd.Series(ys).rank()
    return Corr(xranks, yranks)

# %%
print(Corr(homeWon, awayLost))
print(SpearmanCorr(homeWon, awayLost))
# Out:
# 0.36992218337675326
# 0.06717901546277678

# %% [markdown]
# SECTION 6

# %%
import random

class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %%
data = df.homeWon.values, df.homeLost.values
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.0

# %%
ht.actual, ht.MaxTestStat()
# Out:
# (8.750651041666666, 1.1842447916666679)

# %% [markdown]
# SECTION 7

# %% [markdown]
# The p-value is 0.0. The effect of a difference in the distributions of both variables is statistically significant.
